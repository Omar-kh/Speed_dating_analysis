# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./Data/Speed Dating Data.csv", encoding="ISO-8859-1")

# %%
# Let's have a look at our dataset
df.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  ...  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4  ...
# 1    1  1.0       0    1       1     1     10         7       NaN      3  ...
# 2    1  1.0       0    1       1     1     10         7       NaN     10  ...
# 3    1  1.0       0    1       1     1     10         7       NaN      5  ...
# 4    1  1.0       0    1       1     1     10         7       NaN      7  ...
#
#    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  intel5_3  \
# 0      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 1      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 2      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 3      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 4      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
#
#    fun5_3  amb5_3
# 0     NaN     NaN
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN
#
# [5 rows x 195 columns]

# %%
# What are our variables
df.columns
# Out:
# Index(['iid', 'id', 'gender', 'idg', 'condtn', 'wave', 'round', 'position',
#        'positin1', 'order',
#        ...
#        'attr3_3', 'sinc3_3', 'intel3_3', 'fun3_3', 'amb3_3', 'attr5_3',
#        'sinc5_3', 'intel5_3', 'fun5_3', 'amb5_3'],
#       dtype='object', length=195)

# %%
# How many inputs de we have
df.shape
# Out:
# (8378, 195)

# %%
# How many null values do we have
na_calc = df.isnull().sum() / len(df)

# %%
na_calc
# Out:
# iid         0.000000
# id          0.000119
# gender      0.000000
# idg         0.000000
# condtn      0.000000
# wave        0.000000
# round       0.000000
# position    0.000000
# positin1    0.220339
# order       0.000000
# partner     0.000000
# pid         0.001194
# match       0.000000
# int_corr    0.018859
# samerace    0.000000
# age_o       0.012413
# race_o      0.008713
# pf_o_att    0.010623
# pf_o_sin    0.010623
# pf_o_int    0.010623
# pf_o_fun    0.011697
# pf_o_amb    0.012772
# pf_o_sha    0.015397
# dec_o       0.000000
# attr_o      0.025304
# sinc_o      0.034256
# intel_o     0.036524
# fun_o       0.042970
# amb_o       0.086178
# shar_o      0.128432
#               ...
# amb1_3      0.525662
# shar1_3     0.525662
# attr7_3     0.759370
# sinc7_3     0.759370
# intel7_3    0.759370
# fun7_3      0.759370
# amb7_3      0.759370
# shar7_3     0.759370
# attr4_3     0.646813
# sinc4_3     0.646813
# intel4_3    0.646813
# fun4_3      0.646813
# amb4_3      0.646813
# shar4_3     0.646813
# attr2_3     0.646813
# sinc2_3     0.646813
# intel2_3    0.646813
# fun2_3      0.646813
# amb2_3      0.646813
# shar2_3     0.759370
# attr3_3     0.525662
# sinc3_3     0.525662
# intel3_3    0.525662
# fun3_3      0.525662
# amb3_3      0.525662
# attr5_3     0.759370
# sinc5_3     0.759370
# intel5_3    0.759370
# fun5_3      0.759370
# amb5_3      0.759370
# Length: 195, dtype: float64

# %%
# Let's get rid of all the variables that have more than 50% of null values
filtered_na_calc = na_calc[na_calc < 0.5].index

# %%
clean_df = df.loc[:,filtered_na_calc]

# %%
clean_df.income = clean_df.income.fillna('0')

# %%
# Finally we drop the inputs where we have null values, just so we can proceed quickly with a first version of our dataset
dating = clean_df.dropna()

# %%
# If we look at our dataset, we will find an income variable. This variable seems important, however...
# ... if we look at it we realize that it's defined as a string, which is not exactly relevant for the rest of our analysis
# So we decide to put it in a integer format for the sake of better results
dating.income = dating.income.apply(lambda x: int(float(x.replace(',', ''))))
# Out:
# c:\users\omar\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
# We retrieve then all the columns that aren't numeral variables
non_num_cols = []
for col in dating.columns:
    if dating[col].dtypes == 'object':
        non_num_cols.append(col)
non_num_cols
# Out:
# ['field', 'undergra', 'from', 'zipcode', 'career']

# %%
# And create a duplicate dataset with only numbers. This helps us:
# - to loop over the dataset variables while checking their correlation with the match outcome
# - perform some computations later (probably)
dating_with_only_numbers = dating.drop(non_num_cols, axis=1)
col_corr_with_match = [(col, abs(dating_with_only_numbers["match"].corr(dating_with_only_numbers[col]))) for col in dating_with_only_numbers.columns]

# %%
# Let's check what variables influence the most the match outcome
def sortSecond(val):
    return val[1]
col_corr_with_match.sort(key = sortSecond, reverse = True)
col_corr_with_match
# Out:
# [('match', 1.0),
#  ('dec', 0.5768097297490473),
#  ('dec_o', 0.48177261874326127),
#  ('like', 0.3385724653766807),
#  ('fun', 0.2947812664188112),
#  ('like_o', 0.28427370986356976),
#  ('attr', 0.282170015517321),
#  ('shar', 0.27711941333070766),
#  ('fun_o', 0.2605320860210455),
#  ('prob', 0.2534097287170861),
#  ('shar_o', 0.23899045843175806),
#  ('attr_o', 0.2383761275440273),
#  ('prob_o', 0.22894670295595176),
#  ('intel', 0.2223869912571761),
#  ('sinc', 0.22190690601411506),
#  ('match_es', 0.1965415685429445),
#  ('intel_o', 0.18040298966420867),
#  ('sinc_o', 0.1667220994209169),
#  ('amb', 0.14899215062420695),
#  ('amb_o', 0.13741814863591423),
#  ('satis_2', 0.11425731086116916),
#  ('shar1_1', 0.11171854743876858),
#  ('shar1_2', 0.10655485370089565),
#  ('intel2_2', 0.1002904252783247),
#  ('met_o', 0.09817530022668447),
#  ('sinc4_1', 0.09236685492181294),
#  ('music', 0.09045847920529558),
#  ('intel4_1', 0.0771487208069524),
#  ('fun1_2', 0.07417986353625296),
#  ('sinc5_2', 0.07399586120558015),
#  ('fun1_1', 0.07181552256396205),
#  ('intel2_1', 0.06994467240890541),
#  ('length', 0.06982200036084601),
#  ('movies', 0.06401777028283318),
#  ('sinc4_2', 0.06116346130813631),
#  ('pf_o_sin', 0.06082569555663908),
#  ('concerts', 0.059721805294015703),
#  ('fun3_2', 0.05622635714512657),
#  ('hiking', 0.05475627463396476),
#  ('numdat_2', 0.05385035726095488),
#  ('yoga', 0.04937881845513269),
#  ('sinc1_2', 0.04853155741403538),
#  ('clubbing', 0.047824177718297146),
#  ('date', 0.04603410821274207),
#  ('intel5_2', 0.04339045804212703),
#  ('shar2_1', 0.04320819062715356),
#  ('attr3_2', 0.042158988196943956),
#  ('wave', 0.0415743081694884),
#  ('intel5_1', 0.04098145032342519),
#  ('fun4_2', 0.040790119621952704),
#  ('age_o', 0.040724044247349746),
#  ('shar2_2', 0.039890922340733395),
#  ('gaming', 0.0397720112452241),
#  ('amb5_1', 0.0392566763839843),
#  ('income', 0.03917484091340612),
#  ('pf_o_fun', 0.03876083759340151),
#  ('tvsports', 0.038703640123039715),
#  ('iid', 0.03792393675676785),
#  ('exphappy', 0.037692035245403425),
#  ('pid', 0.037627812263012435),
#  ('field_cd', 0.03687823339100731),
#  ('round', 0.03662151709918989),
#  ('met', 0.03616993159413161),
#  ('attr4_2', 0.035929231250882834),
#  ('sinc5_1', 0.034508810670597474),
#  ('id', 0.03316126908854551),
#  ('samerace', 0.032653818143719905),
#  ('idg', 0.03235005322136216),
#  ('exercise', 0.03192651002080316),
#  ('attr4_1', 0.030756405198340244),
#  ('amb2_1', 0.0297042386877041),
#  ('sinc2_1', 0.02757429549668095),
#  ('intel3_1', 0.02702562436497425),
#  ('fun2_1', 0.026517523223425748),
#  ('attr2_2', 0.026412780259429496),
#  ('fun5_2', 0.025816915977602693),
#  ('int_corr', 0.025702698247916645),
#  ('amb2_2', 0.025457233051234738),
#  ('attr5_2', 0.025185190356795607),
#  ('dining', 0.025049309066114283),
#  ('fun5_1', 0.024949477476418527),
#  ('amb1_1', 0.023970774352817904),
#  ('shar4_1', 0.023104806370342533),
#  ('art', 0.022922858414960546),
#  ('age', 0.021897264370771646),
#  ('gender', 0.021893099176855352),
#  ('amb4_2', 0.021082054146725645),
#  ('shar4_2', 0.020823211159357074),
#  ('sinc3_2', 0.02081533851597135),
#  ('pf_o_sha', 0.020672307534083775),
#  ('tv', 0.020156357002591434),
#  ('condtn', 0.02015153469467832),
#  ('order', 0.02004782175514365),
#  ('intel4_2', 0.019725648807258113),
#  ('fun2_2', 0.019410323170563088),
#  ('career_c', 0.018582664196524396),
#  ('imprace', 0.018401587121742294),
#  ('race_o', 0.017839466080442814),
#  ('amb1_2', 0.01780895241952019),
#  ('attr5_1', 0.01692027947816786),
#  ('fun4_1', 0.01669890767034981),
#  ('attr1_2', 0.016423450202634658),
#  ('attr2_1', 0.016400199495361867),
#  ('attr3_1', 0.01515494860512909),
#  ('pf_o_att', 0.01494888639599485),
#  ('go_out', 0.013786949860861384),
#  ('intel1_2', 0.013429850818150164),
#  ('amb4_1', 0.012991647380284745),
#  ('pf_o_amb', 0.01289683872829125),
#  ('sinc1_1', 0.012765475053744615),
#  ('amb5_2', 0.012345469959511073),
#  ('imprelig', 0.012046149643515467),
#  ('museums', 0.011389284763758317),
#  ('fun3_1', 0.010689733378413687),
#  ('amb3_2', 0.008979487212331353),
#  ('amb3_1', 0.008820741776439768),
#  ('sinc3_1', 0.008295873122440204),
#  ('intel3_2', 0.007412964784764854),
#  ('intel1_1', 0.0072552726032846585),
#  ('race', 0.00698975652266205),
#  ('attr1_1', 0.006874753494960945),
#  ('theater', 0.006488801403135881),
#  ('goal', 0.0057135347251008),
#  ('position', 0.005093482060574926),
#  ('pf_o_int', 0.004761936074760645),
#  ('partner', 0.004191658565322711),
#  ('positin1', 0.002995247479660816),
#  ('sports', 0.0025318538501700526),
#  ('shopping', 0.002401859544560329),
#  ('reading', 0.0009108204010150114),
#  ('sinc2_2', 0.00025235686501314604)]

# %%
# There is a definitely high correlation between the decision and the match
# How about we check the probability of matching for the people who make the most favorable decisions
# First let's define our delimiters:
# - the first attempt would be to classify the participants between those who decide positively more than 50% of the time and the others

# First we get the number of people met by each individual
met_by_person = [(iid, len(dating[dating.iid == iid])) for iid in dating.iid]
met_by_person = list(dict.fromkeys(met_by_person))
met_by_person.sort()

# %%
# Then, we get the number of positive decisions by person
# First, let's create our matrix
dec_count_matrix = dating.groupby("iid").sum()["dec"]
# Then, we create a list with the percentage of decision
dec_per_by_person = [(per[0], dec_count_matrix[per[0]] / per[1]) for per in met_by_person]

# %%
# A far better method
dec_per_by_person = dating.groupby("iid").sum()["dec"] / dating.groupby("iid").count()["dec"]

# %%
# Then we merge our data based on the iid
dating = dating.merge(dec_per_by_person, on = "iid")
dating_with_only_numbers = dating_with_only_numbers.merge(dec_per_by_person, on = "iid")

# %%
dating = dating.rename(index = str, columns={"dec_y": "dec_perc", "dec_x": "dec"})

# %%
dating_with_only_numbers = dating_with_only_numbers.rename(index = str, columns={"dec_y": "dec_perc", "dec_x": "dec"})

# %%
dating["positiveness"] = pd.cut(x = dating.dec_perc, bins = [0, 0.5, 1], labels = ["Less than 50% positive decisions", "More than 50% positive decisions"])

# %%
dating_with_only_numbers["positiveness"] = pd.cut(x = dating_with_only_numbers.dec_perc, bins = [0, 0.5, 1], labels = ["Less than 50% positive decisions", "More than 50% positive decisions"])

# %%
sns.barplot("positiveness", "match", data = dating)

# %%
# Let's take the more positive participants
dating_positive = dating[dating.positiveness == "More than 50% positive decisions"]

# %%
dating_with_numonly_positive = dating_with_only_numbers[dating_with_only_numbers.positiveness == "More than 50% positive decisions"]

# %%
dating_with_numonly_positive = dating_with_numonly_positive.drop("positiveness", axis = 1)

# %%
# Now we check the correlation again with the match outcome for all the variables
# We will drop obvious variables such as the partner's decision, and the person's decision
col_corr_with_match = [(col, abs(dating_with_numonly_positive["match"].corr(dating_with_numonly_positive[col]))) for col in dating_with_numonly_positive.columns]
col_corr_with_match.sort(key = sortSecond, reverse = True)
col_corr_with_match = col_corr_with_match[3:]
col_corr_with_match
# Out:
# [('like_o', 0.4045719803446816),
#  ('attr_o', 0.3998942000610629),
#  ('shar_o', 0.38255349121963594),
#  ('fun_o', 0.37610922282538545),
#  ('like', 0.30977272970329683),
#  ('prob_o', 0.30029175113146744),
#  ('sinc_o', 0.27263571347682186),
#  ('fun', 0.2712906411490544),
#  ('intel', 0.2606539869749898),
#  ('intel_o', 0.25545201414573815),
#  ('sinc', 0.2291177147109717),
#  ('shar', 0.21554956623029378),
#  ('attr', 0.20638055676519906),
#  ('attr4_2', 0.19318562698956943),
#  ('exphappy', 0.18999573168812178),
#  ('sinc4_1', 0.181224528646329),
#  ('prob', 0.17232476134499858),
#  ('amb', 0.1723186942761011),
#  ('shar1_1', 0.16909070490190656),
#  ('shar1_2', 0.1632291824769507),
#  ('met_o', 0.15628889144138033),
#  ('intel5_2', 0.154531329808481),
#  ('hiking', 0.15364589844075338),
#  ('sinc4_2', 0.1531477526803264),
#  ('wave', 0.15078026977545422),
#  ('amb4_2', 0.1473552819899075),
#  ('amb5_2', 0.144990347522062),
#  ('amb_o', 0.14305187508939732),
#  ('iid', 0.14051967626955905),
#  ('pid', 0.13840172144121532),
#  ('intel3_1', 0.13733651468137786),
#  ('sports', 0.13693367294196634),
#  ('sinc5_2', 0.132831840443852),
#  ('intel2_1', 0.12172431372590273),
#  ('intel4_2', 0.11850813322851601),
#  ('imprelig', 0.11744136114806024),
#  ('music', 0.11469710224183391),
#  ('positin1', 0.10923302468612994),
#  ('concerts', 0.10218619552465757),
#  ('fun3_2', 0.10023559630646434),
#  ('field_cd', 0.10017351548845035),
#  ('attr1_2', 0.0997492254523853),
#  ('attr4_1', 0.09786853840122953),
#  ('reading', 0.09615537670745666),
#  ('satis_2', 0.09359508397699509),
#  ('amb3_2', 0.09212655384923993),
#  ('fun1_1', 0.08997462638915564),
#  ('go_out', 0.08878878120420189),
#  ('goal', 0.08787793586434452),
#  ('movies', 0.08758426871059265),
#  ('fun2_1', 0.08663991350848076),
#  ('met', 0.08584970602183174),
#  ('sinc5_1', 0.08509258086763852),
#  ('sinc1_1', 0.08268823231734866),
#  ('shar4_2', 0.08165011762246233),
#  ('amb2_2', 0.07997744390904316),
#  ('fun5_2', 0.0789352036469316),
#  ('attr5_2', 0.07687606569372173),
#  ('match_es', 0.07404354589047249),
#  ('attr1_1', 0.06954706456641224),
#  ('tvsports', 0.06748081137389951),
#  ('shar2_2', 0.06660854411228764),
#  ('dec_perc', 0.06505566305411047),
#  ('amb2_1', 0.06501575153256246),
#  ('intel2_2', 0.06258422790447116),
#  ('shar2_1', 0.06163527160547938),
#  ('shar4_1', 0.060708776361745126),
#  ('race_o', 0.06030194665936631),
#  ('idg', 0.059526634190140926),
#  ('pf_o_amb', 0.059426243670651975),
#  ('attr2_2', 0.058693782732585686),
#  ('id', 0.05470899150061567),
#  ('exercise', 0.054680540198291334),
#  ('length', 0.05452439710328374),
#  ('position', 0.054508640363612894),
#  ('attr3_2', 0.05289036412757521),
#  ('yoga', 0.051027048211836915),
#  ('age_o', 0.05077044325868299),
#  ('order', 0.049995325572424976),
#  ('amb5_1', 0.04937112560245594),
#  ('tv', 0.047817646804910796),
#  ('intel1_1', 0.04770479878821221),
#  ('theater', 0.04722462828646181),
#  ('attr5_1', 0.04638512927135909),
#  ('imprace', 0.04422244820519163),
#  ('fun1_2', 0.04286960352392345),
#  ('attr3_1', 0.042848532990378024),
#  ('sinc3_2', 0.042780219091488554),
#  ('partner', 0.04098601263914523),
#  ('pf_o_int', 0.04070620443602775),
#  ('clubbing', 0.038828593549529826),
#  ('intel4_1', 0.03681622042478544),
#  ('pf_o_sin', 0.03473707258533776),
#  ('dining', 0.033954079414660984),
#  ('amb1_1', 0.03075052283526132),
#  ('round', 0.027972367320459504),
#  ('fun5_1', 0.027412333544106975),
#  ('date', 0.027010948098915036),
#  ('sinc1_2', 0.026510116204023205),
#  ('pf_o_sha', 0.025291163028243115),
#  ('amb3_1', 0.025167201288031783),
#  ('income', 0.023306218465788175),
#  ('numdat_2', 0.021373200399951685),
#  ('sinc3_1', 0.02099756758208885),
#  ('amb1_2', 0.020452882749353335),
#  ('sinc2_1', 0.019833036757414376),
#  ('fun4_2', 0.017595279128306728),
#  ('fun4_1', 0.017123104724667746),
#  ('intel5_1', 0.016301783651912354),
#  ('art', 0.015523930567462155),
#  ('amb4_1', 0.014780583048671811),
#  ('int_corr', 0.014097794266815478),
#  ('pf_o_att', 0.012983392944018401),
#  ('museums', 0.011900045071611487),
#  ('condtn', 0.011877588397591779),
#  ('sinc2_2', 0.011620369284331019),
#  ('gaming', 0.010974926393297297),
#  ('attr2_1', 0.010869993377667435),
#  ('intel3_2', 0.010645915050760272),
#  ('shopping', 0.009597849049142357),
#  ('age', 0.008788421218218571),
#  ('intel1_2', 0.008592498840142883),
#  ('gender', 0.00839270543739455),
#  ('fun2_2', 0.007959974532223033),
#  ('pf_o_fun', 0.007113374417499739),
#  ('career_c', 0.004273839439208296),
#  ('race', 0.0018769665956365508),
#  ('fun3_1', 0.0005158454412068064),
#  ('samerace', 0.0001117132540228046)]

# %%
plt.figure(figsize = (15,30))
sns.scatterplot(list(dict(col_corr_with_match).values()), list(dict(col_corr_with_match).keys()))

# %%
# Okay, let's see what are your chances if you are a positive decisioner depending on how well you have been liked by your partner
sns.barplot("like_o", "match", data = dating_positive)

# %%
# Right, we can set our likeability threshold to 6,5
dating_positive["liked_by_partner"] = pd.cut(dating_positive["like_o"], bins = [0,6.5,10], labels=["Not liked", "Well liked"])
# Out:
# c:\users\omar\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
plt.figure(figsize=(5,5))
sns.barplot("liked_by_partner", "match", data = dating_positive, hue="gender")

# %%
# That's good and all, but "being liked" doesn't tell us much about a person's individual traits
# Let's check them
sns.barplot("attr_o", "match", data = dating_positive, hue="gender")

# %%
sns.barplot("income_cat", "match", data = dating_positive, hue="gender")

# %%
dating_positive["income_cat"] = dating_positive.income.apply(lambda x: "Very rich" if x > 50000
                                          else "Rich" if x > 25000
                                          else "Poor" if x > 10000
                                          else "Very poor")
# Out:
# c:\users\omar\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dating.loc[:, ["income", "income_cat"]]
# Out:
#       income income_cat
# 3409   44346       Rich
# 3413   44346       Rich
# 3414   44346       Rich
# 3415   44346       Rich
# 3427   42225       Rich
# 3428   42225       Rich
# 3430   42225       Rich
# 3431   42225       Rich
# 3432   42225       Rich
# 3433   42225       Rich
# 3440   37405       Rich
# 3445   28524       Rich
# 3446   28524       Rich
# 3448   28524       Rich
# 3449   28524       Rich
# 3450   28524       Rich
# 3451   28524       Rich
# 3452   28524       Rich
# 3463   61141  Very rich
# 3464   61141  Very rich
# 3466   61141  Very rich
# 3467   61141  Very rich
# 3468   61141  Very rich
# 3469   61141  Very rich
# 3472    8607  Very poor
# 3473    8607  Very poor
# 3475    8607  Very poor
# 3476    8607  Very poor
# 3477    8607  Very poor
# 3478    8607  Very poor
# ...      ...        ...
# 8182   36673       Rich
# 8184   36673       Rich
# 8185   36673       Rich
# 8186   36673       Rich
# 8187   36673       Rich
# 8189   36673       Rich
# 8190   36673       Rich
# 8191   36673       Rich
# 8194   36673       Rich
# 8195   36673       Rich
# 8196   36673       Rich
# 8197   36673       Rich
# 8198   36673       Rich
# 8201   36673       Rich
# 8334   55138  Very rich
# 8336   55138  Very rich
# 8338   55138  Very rich
# 8339   55138  Very rich
# 8341   55138  Very rich
# 8342   55138  Very rich
# 8345   55138  Very rich
# 8346   55138  Very rich
# 8347   55138  Very rich
# 8348   55138  Very rich
# 8349   55138  Very rich
# 8350   55138  Very rich
# 8351   55138  Very rich
# 8352   55138  Very rich
# 8354   55138  Very rich
# 8355   55138  Very rich
#
# [1283 rows x 2 columns]

# %%
sns.barplot("income_cat", "match", hue= "gender", data = dating)

# %%
dating["diff_age"] = abs(dating.age - dating.age_o)
# Out:
# c:\users\omar\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dating["diff_age_cat"] = pd.cut(dating.diff_age, bins=[2,4,6,8,10,12], labels=["very small", "small", "medium", "big", "very big"])
# Out:
# c:\users\omar\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sns.barplot("diff_age_cat", "match", data = dating, hue = "gender")

# %%
big_agediff_lowinc = dating[(dating.diff_age >= 8) & (dating.income_cat == "Poor")]

# %%
sns.countplot("gender", data = big_agediff_lowinc)

# %%
plt.figure(figsize = (20,20))
sns.barplot("wave", "match", data = dating, hue="race")

# %%
sns.barplot("gender", "dec", data = dating)

# %%
pd.crosstab([dating["wave"], dating["gender"], dating["race"]], dating["match"])
# Out:
# match              0   1
# wave gender race
# 10   0      2.0    6   2
#             4.0   15   3
#             6.0    4   0
#      1      6.0    6   3
# 11   0      1.0   12   5
#             2.0   97   7
#             3.0    5   7
#             4.0   45   7
#             6.0    8   2
#      1      1.0   15   3
#             2.0   47  11
#             4.0   14   4
# 12   0      2.0   62  11
#             4.0   18   2
#      1      2.0   22   7
#             4.0   10   0
# 14   0      2.0   37  11
#             3.0   10   4
#             4.0   25   3
#      1      2.0   55  10
#             4.0   13   2
# 15   0      2.0   78   9
#             4.0   11   2
#      1      1.0   11   0
#             2.0   21   1
# 16   0      2.0    6   2
#             4.0    9   1
#      1      2.0    4   5
#             4.0    2   1
# 17   0      2.0   36  10
#             4.0   12   0
#             6.0   11   2
#      1      2.0    8   3
#             3.0    6   0
#             6.0    7   2
# 18   0      2.0    4   0
#             4.0    4   0
# 19   0      1.0    7   3
#             2.0   15   6
#             4.0    9   5
#             6.0    9   3
#      1      2.0   17   5
#             4.0    2   1
#             6.0   10   8
# 20   0      1.0    5   1
#             2.0   10   3
#             4.0    3   0
#      1      2.0   10   2
#             4.0   14   2
# 21   0      2.0   74  12
#             4.0   20  19
#             6.0   37   0
#      1      1.0   14   2
#             2.0   10   7
#             4.0   38   2

# %%
corr = dating.drop(["iid", "id"], axis=1).corr()
for col in corr.columns:
    corr[col] = corr[col].apply(lambda x: abs(x) if abs(x) > 0.6 else 0)
#Same as dating.applymap

# %%
plt.figure(figsize = (20, 20))
sns.heatmap(corr)

# %%
sns.countplot("match", data = clean_df)

# %%
match_age_dist = matched.age.dropna()
unmatch_age_dist = unmatched.age.dropna()
age_dist = df.age.dropna()
sns.distplot(match_age_dist)

# %%
sns.distplot(unmatch_age_dist)

# %%
sns.distplot(age_dist)

# %%
plt.figure(figsize=(20, 80))
sns.barplot("match", "career", data = df)

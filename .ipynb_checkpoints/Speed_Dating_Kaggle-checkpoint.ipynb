# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("./Data/Speed Dating Data.csv", encoding="ISO-8859-1")

# %%
na_calc = df.isnull().sum() / len(df)

# %%
# Let's get rid of all the variables that have more than 50% of null values
filtered_na_calc = na_calc[na_calc < 0.05].index

# %%
clean_df = df.loc[:,filtered_na_calc]

# %%
# Finally we drop the inputs where we have null values, just so we can proceed quickly with a first version of our dataset
dating = clean_df.dropna()
dating.columns
# Out:
# Index(['iid', 'id', 'gender', 'idg', 'condtn', 'wave', 'round', 'position',
#        'order', 'partner', 'pid', 'match', 'int_corr', 'samerace', 'age_o',
#        'race_o', 'pf_o_att', 'pf_o_sin', 'pf_o_int', 'pf_o_fun', 'pf_o_amb',
#        'pf_o_sha', 'dec_o', 'attr_o', 'sinc_o', 'intel_o', 'fun_o', 'like_o',
#        'prob_o', 'met_o', 'age', 'field', 'field_cd', 'race', 'imprace',
#        'imprelig', 'from', 'goal', 'date', 'go_out', 'career', 'career_c',
#        'sports', 'tvsports', 'exercise', 'dining', 'museums', 'art', 'hiking',
#        'gaming', 'clubbing', 'reading', 'tv', 'theater', 'movies', 'concerts',
#        'music', 'shopping', 'yoga', 'exphappy', 'attr1_1', 'sinc1_1',
#        'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1', 'attr2_1', 'sinc2_1',
#        'intel2_1', 'fun2_1', 'amb2_1', 'shar2_1', 'attr3_1', 'sinc3_1',
#        'fun3_1', 'intel3_1', 'amb3_1', 'dec', 'attr', 'sinc', 'intel', 'fun',
#        'like', 'prob', 'met'],
#       dtype='object')

# %%
plt.figure(figsize = (20,20))
sns.set(palette="Set2")
sns.heatmap(dating.corr(), cmap="Set2")

# %%
# Let's isolate numeric values from non numeric ones
dating3 = dating.loc[:, dating.dtypes[dating.dtypes == 'object'].index]
dating2 = dating.loc[:, dating.dtypes[dating.dtypes != 'object'].index]

# %%
dating_int = dating.loc[:, ["concerts", "music", "art", "shopping", "yoga", "gender"]]

# %%
sns.pairplot(dating_int, hue="gender", diag_kind = "hist")

# %%
g = sns.FacetGrid(dating, col="gender")
g = g.map(plt.hist, 'dec_o')

# %%
# Broken hearted
dating.loc[:,"brheart"]=dating.dec+dating.dec_o
dating.loc[:,"brheartm"]=dating.dec*dating.dec_o
dating_brheart_per = len(dating[(dating.brheart==1) & (dating.brheartm==0)])  / len(dating.index) 
dating.loc[:,["dec", "dec_o", "brheart"]]
# Out:
#       dec  dec_o  brheart
# 30      0      0        0
# 31      0      0        0
# 33      1      1        2
# 34      0      1        1
# 35      0      1        1
# 36      0      1        1
# 37      0      0        0
# 38      1      1        2
# 39      1      0        1
# 40      0      0        0
# 41      0      0        0
# 42      0      1        1
# 43      1      1        2
# 44      0      0        0
# 45      1      0        1
# 46      1      0        1
# 47      1      0        1
# 48      1      1        2
# 49      1      0        1
# 50      1      0        1
# 51      1      0        1
# 52      0      1        1
# 53      1      1        2
# 54      0      1        1
# 55      0      1        1
# 56      1      0        1
# 57      0      0        0
# 58      1      1        2
# 59      1      0        1
# 60      0      0        0
# ...   ...    ...      ...
# 8338    1      0        1
# 8339    0      1        1
# 8340    1      0        1
# 8341    1      1        2
# 8342    0      0        0
# 8343    1      0        1
# 8345    0      0        0
# 8346    1      1        2
# 8347    1      0        1
# 8348    0      1        1
# 8349    0      1        1
# 8350    0      1        1
# 8351    0      1        1
# 8352    0      0        0
# 8354    0      1        1
# 8355    0      0        0
# 8357    1      1        2
# 8358    0      1        1
# 8361    0      1        1
# 8363    1      1        2
# 8364    1      0        1
# 8365    0      1        1
# 8367    0      0        0
# 8368    0      1        1
# 8369    0      1        1
# 8370    0      1        1
# 8371    1      1        2
# 8372    0      0        0
# 8374    0      0        0
# 8376    0      1        1
#
# [6777 rows x 3 columns]

# %%
no_love_count = len(dating[(dating['dec_o']==0) & (dating['dec']==1)]) 
+ len(dating[(dating['dec_o']==1) & (dating['dec']==0)])
perc_broken_heart = no_love_count / len(dating.index)
perc_broken_heart*100
# Out:
# 26.102995425704588
